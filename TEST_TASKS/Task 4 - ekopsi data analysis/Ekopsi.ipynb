# %% [markdown]
# ## Description
# There is dataset about income of employees in the hot-rolling manufacture for 1 year.<br>
# The data also includes job specifics.<br>
# Income consists of salary, bonuses, additional payments and allowances.<br>
#
# ## Task
# reveal the common income formula;<br>
# formula should calculate the income up to a whole number;<br>
# reveal the relationship between the components of income;<br>
# check result;

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
# %matplotlib inline

# %%
# Read data from Excel

data = pd.read_excel('/Users/ivankudravcev/Studying/Data/Задание 5.0 2 версия.xlsx')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Read data from Excel
# ----> 3 data = pd.read_excel('/Users/ivankudravcev/Studying/Data/Задание 5.0 2 версия.xlsx')
#       4 data
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/ivankudravcev/Studying/Data/Задание 5.0 2 версия.xlsx'

# %% [markdown]
# ## Exploratory data analysis

# %%
# Rename columns

data.rename(columns={'FIO' : 'Name', 'Месяц' : 'Date', 'Профессия' : 'Profession', 'Разряд': 'Class',
                     'Оборудование' : 'Equipment', 'Вредность (балл.)' : 'Harm', 
                     'Объем производства' : 'Prod_valume', 'Доход' : 'Income'}, inplace=True)

data.head()
# Out:
#             Name       Date Profession  Class           Equipment  Harm  \
# 0  Абрамов Е. Д. 2009-01-01    Уборщик      3  Пилигримовые станы    18
# 1  Абрамов Е. Д. 2009-02-01    Уборщик      3  Пилигримовые станы    18
# 2  Абрамов Е. Д. 2009-03-01    Уборщик      3  Пилигримовые станы    18
# 3  Абрамов Е. Д. 2009-04-01    Уборщик      3  Пилигримовые станы    18
# 4  Абрамов Е. Д. 2009-05-01    Уборщик      3  Пилигримовые станы    18
#
#    Prod_valume        Income
# 0          580  16638.000000
# 1          790  16638.000000
# 2          820  16638.000000
# 3         1200  19396.411765
# 4         1250  19790.470588

# %%
# Check the types and Nan's count

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         2400 non-null   object
#  1   Date         2400 non-null   datetime64[ns]
#  2   Profession   2400 non-null   object
#  3   Class        2400 non-null   int64
#  4   Equipment    2400 non-null   object
#  5   Harm         2400 non-null   int64
#  6   Prod_valume  2400 non-null   int64
#  7   Income       2400 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 150.1+ KB

# %%
# How many unique in each

unique_values = {}

print('Unique:')
for column in data.columns:
    unique_values.update({'column' : data[column].unique})
    print(f'{column} : {len(data[column].unique())}')
# Out:
# Unique:
# Name : 200
# Date : 12
# Profession : 9
# Class : 5
# Equipment : 9
# Harm : 6
# Prod_valume : 12
# Income : 346

# %%
# What is unique

print(unique_values['Profession'])
print(unique_values['Class'])
print(unique_values['Equipment'])
print(unique_values['Harm'])
print(unique_values['Prod_valume'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/26/6n64wy9s3v9bjxfzjrrwndyh0000gn/T/ipykernel_96514/881024338.py in <module>
#       1 # What is unique
#       2
# ----> 3 print(unique_values('Profession'))
#       4 print(unique_values['Class'])
#       5 print(unique_values['Equipment'])
#
# TypeError: 'dict' object is not callable

# %% [markdown]
# 2400 records and 8 columns;
# no Nans;

# %% [markdown]
# Profession, Class, Equipment - better modify to categorial;

# %%
data['Profession'] = data['Profession'].astype('category')
data['Class'] = data['Class'].astype('category')
data['Equipment'] = data['Equipment'].astype('category')

# %%
data.describe()
# Out:
#              Class         Harm  Prod_valume        Income
# count  2400.000000  2400.000000  2400.000000   2400.000000
# mean      4.900000    15.785000   988.333333  21665.570570
# std       1.371417     6.567857   230.982220   4686.885527
# min       3.000000     0.000000   580.000000  12180.000000
# 25%       4.000000    14.750000   805.000000  18076.500000
# 50%       5.000000    18.000000   985.000000  21057.300000
# 75%       6.000000    19.000000  1185.000000  25105.764706
# max       7.000000    22.000000  1400.000000  36076.764706

# %% [markdown]
# no negative;<br>
# looks normal;

# %% [markdown]
# check how income depends from other variables:

# %%
vars = ['Profession', 'Class', 'Equipment', 'Harm', 'Prod_valume']

fig, axes = plt.subplots(figsize=(15, 20), ncols=2, nrows=3)
for i, col in enumerate(vars):
    Y = col.unique()
    ax = axes[i//2, i%2]
    sns.boxplot(x='Income', y=Y, data=data, ax=ax)
    ax.set_xlabel(col)
    ax.set_title(f'{i+1}', fontsize='16')
    

# axes[2][1].set_visible(False)

# plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/26/6n64wy9s3v9bjxfzjrrwndyh0000gn/T/ipykernel_96514/93748192.py in <module>
#       3 fig, axes = plt.subplots(figsize=(15, 20), ncols=2, nrows=3)
#       4 for i, col in enumerate(vars):
# ----> 5     Y = col.unique()
#       6     ax = axes[i//2, i%2]
#       7     sns.boxplot(x='Income', y=Y, data=data, ax=ax)
#
# AttributeError: 'str' object has no attribute 'unique'

# %% [markdown]
# #### вероятнее всего колебания дохода обусловлены отпусками и т.п., каких-то очевидных зависимостей нет;
# #### на производственных предприятиях, фактор вредности почти всегда отражается на доходе, но здесь связь не очевидна - скорее всего из-за влияния какого-то искажающего фактора, который сильно влияет на доход;
# #### объем производства начинает оказывать влияние на доход только после уровня 820;
# #### доход линейно зависим от разряда;
# #### вальцовщики, контролеры качества и нагревальщики - самые богатые люди на производстве, а вот с уборщиков взять нечего;
# #### скорее всего оборудование и вредность - зависимы, т.е. оборудование косвенно через вредность оказывает влияние на доход;

# %% [markdown]
# ## Анализ зависимости дохода от вредности
# #### Сгруппируем записи по 3 разряду и посомтрим на значения доходов и вредности.

# %%
data_r3 = data.loc[data.Разряд==3]

fig, axes = plt.subplots(figsize=(15, 5), ncols=2, nrows=1)

ax = axes[0]
ax.hist('Доход', data=data_r3, bins=30)
ax.set_title('Доход')

ax = axes[1]
ax.hist('Вредность (балл.)', data=data_r3)
ax.set_title('Вредность')

plt.show()

# %% [markdown]
# #### Наблюдается высокая дисперсия значений доходов.
# #### Посомтрим как отличаются доходы в зависимости от вредности:

# %%
data_r3_v0 = data_r3.loc[data['Вредность (балл.)']==0]
data_r3_v18 = data_r3.loc[data['Вредность (балл.)']==18]

fig, axes = plt.subplots(figsize=(15, 5), ncols=2, nrows=1)

ax = axes[0]
ax.hist('Доход', data=data_r3_v0, bins=30)
ax.set_title('Доход raz3 vr0')

ax = axes[1]
ax.hist('Доход', data=data_r3_v18, bins=30)
ax.set_title('Доход raz3 vr18', )

plt.show()

# %%
dr3v0 = np.array([data_r3_v0.Доход.unique()][0])
dr3v0.sort()

dr3v18 = np.array([data_r3_v18.Доход.unique()][0])
dr3v18.sort()

print(f'Доходы разряд - 3, вредность - 0, значений: {len(dr3v0)}')
print(dr3v0)
print()

print(f'Доходы разряд - 3, вредность - 18, значений: {len(dr3v18)}')
print(dr3v18)
print()

print(f'Разница:')
print(dr3v18[:10]-dr3v0[:10])
# Out:
# Доходы разряд - 3, вредность - 0, значений: 25
# [12180.         12789.         12789.         12896.47058824
#  13398.         13398.         13541.29411765 13827.88235294
#  14067.9        14186.11764706 14519.27647059 14544.35294118
#  14687.64705882 14737.8        15045.88235294 15210.67058824
#  15271.57058824 15422.02941176 15798.17647059 15998.78823529
#  16120.58823529 16156.41176471 16550.47058824 16926.61764706
#  17732.64705882]
#
# Доходы разряд - 3, вредность - 18, значений: 24
# [15420.         16029.         16029.         16136.47058824
#  16638.         16781.29411765 17067.88235294 17307.9
#  17426.11764706 17759.27647059 17784.35294118 17927.64705882
#  17977.8        18285.88235294 18450.67058824 18511.57058824
#  18662.02941176 19038.17647059 19238.78823529 19360.58823529
#  19396.41176471 19790.47058824 20166.61764706 20972.64705882]
#
# Разница
# [3240.         3240.         3240.         3240.         3240.
#  3383.29411765 3526.58823529 3480.01764706 3358.21764706 3573.15882353]

# %%
f1 = data['Доход']==12180
f2 = data['Объем производства'] > 820
print('Количество записей объем > 820, доход = 12180:') 
print(len(data.loc[f1&f2]))

f1 = data['Доход']==15420
f2 = data['Объем производства'] > 820
print('Количество записей объем > 820, доход = 15420:') 
print(len(data.loc[f1&f2]))
# Out:
# Количество записей объем > 820, доход = 12180:
# 0
# Количество записей объем > 820, доход = 15420:
# 0

# %% [markdown]
# #### Разница в доходе между 18 и 0 баллами вредности, при прочих равных, __составляет 3240 руб.__. По крайней мере у 3 разряда.
# #### Разница выше 3240 скорее всего обусловлена объемом производства $  ОП > 820 $, т.к. записей выше этого уровня (с доходами 12180 и 15420) нет.
# #### Отбросим записи в которых $ОП > 820$, таким образом исключив влияние объема производства и посмотрим как вредность влияет на доход у работников с другими разрядами. Посмотрим какие значения вредность принимает в каждом разряде, построим точечный график:

# %%
data820 = data.loc[data['Объем производства'] < 950]

plt.scatter('Разряд', 'Вредность (балл.)', data=data820)
plt.title('Распределение вредности по разрядам', fontsize = 16)
plt.xlabel('Разряд', fontsize=14)
plt.ylabel('Вредность (балл.)', fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Возьмем для анализа 7 разряд, т.к. там есть те же уровни вредности, что и в 3.
# #### Проанализируем как доход зависит от вредности в этом случае:

# %%
data820_r7 = data820.loc[data820.Разряд==7]
data820_r7['Вредность (балл.)'].unique()
# Out:
# array([22,  0, 18])

# %%
data820_r7_v0 = data820_r7.loc[data['Вредность (балл.)']==0]
data820_r7_v18 = data820_r7.loc[data['Вредность (балл.)']==18]

dr7v0 = np.array([data820_r7_v0.Доход.unique()][0])
dr7v0.sort()

dr7v18 = np.array([data820_r7_v18.Доход.unique()][0])
dr7v18.sort()

print(f'Доходы разряд - 7, вредность - 0, значений: {len(dr7v0)}')
print(dr7v0)
print()

print(f'Доходы разряд - 7, вредность - 18, значений: {len(dr7v18)}')
print(dr7v18)
print()

print(f'Разница:')
print(dr7v18[:10]-dr7v0[:10])
# Out:
# Доходы разряд - 7, вредность - 0, значений: 5
# [22060. 22060. 23163. 23163. 24266.]
#
# Доходы разряд - 7, вредность - 18, значений: 5
# [25300. 25300. 26403. 26403. 27506.]
#
# Разница:
# [3240. 3240. 3240. 3240. 3240.]

# %% [markdown]
# #### У 3 и 7 разряда разница между 0 и 18 баллами вредности одинкова и составляет 3240.
# #### Предположим, что надбавка за вредность начисляется за каждый балл, тогда:
# #### надбавка за один балл вредности = 3240 / 18 = __180__, следовательно
# #### надбавка за вредность 22 балла  = 22 x 180 = __3960__.
# #### Проверим:

# %%
data820_r7_v22 = data820_r7.loc[data['Вредность (балл.)']==22]


dr7v22 = np.array([data820_r7_v22.Доход.unique()][0])
dr7v22.sort()

print(f'Доходы разряд - 7, вредность - 0, значений: {len(dr7v0)}')
print(dr7v0)
print()

print(f'Доходы разряд - 7, вредность - 22, значений: {len(dr7v22)}')
print(dr7v22)
print()

print(f'Разница:')
print(dr7v22[:10]-dr7v0[:10])
# Out:
# Доходы разряд - 7, вредность - 0, значений: 5
# [22060. 22060. 23163. 23163. 24266.]
#
# Доходы разряд - 7, вредность - 18, значений: 5
# [26020. 26020. 27123. 27123. 28226.]
#
# Разница между первыми 10 значениями:
# [3960. 3960. 3960. 3960. 3960.]

# %% [markdown]
# #### Разница в доходах между 0 и 22 баллами вредности составила __3960__, что подтверждает
# #### предположение о том, что надбавка за вредность сотавляет __180 за 1 балл__.

# %% [markdown]
# ## Анализ зависимости дохода от объема производства (ч. 1)
# #### Исключим влияние фактора вредности отсеив данные с $V > 0$ (V - вредность)

# %%
data_v0 = data.loc[data['Вредность (балл.)'] == 0]
data_v0
# Out:
#                  FIO Месяц                             Профессия Разряд  \
# 96     Антонов В. Т.     1  Контролер качества готовой продукции      7
# 97     Антонов В. Т.     2  Контролер качества готовой продукции      7
# 98     Антонов В. Т.     3  Контролер качества готовой продукции      7
# 99     Антонов В. Т.     4  Контролер качества готовой продукции      7
# 100    Антонов В. Т.     5  Контролер качества готовой продукции      7
# ...              ...   ...                                   ...    ...
# 2299  Чернышев Д. В.     8                               Уборщик      3
# 2300  Чернышев Д. В.     9                               Уборщик      3
# 2301  Чернышев Д. В.    10                               Уборщик      3
# 2302  Чернышев Д. В.    11                               Уборщик      3
# 2303  Чернышев Д. В.    12                               Уборщик      3
#
#                              Оборудование  Вредность (балл.)  \
# 96    Контрольно-измерительная аппаратура                  0
# 97    Контрольно-измерительная аппаратура                  0
# 98    Контрольно-измерительная аппаратура                  0
# 99    Контрольно-измерительная аппаратура                  0
# 100   Контрольно-измерительная аппаратура                  0
# ...                                   ...                ...
# 2299            Вспомогательные помещения                  0
# 2300            Вспомогательные помещения                  0
# 2301            Вспомогательные помещения                  0
# 2302            Вспомогательные помещения                  0
# 2303            Вспомогательные помещения                  0
#
#       Объем производства         Доход
# 96                   580  22060.000000
# 97                   790  22060.000000
# 98                   820  22060.000000
# 99                  1200  26601.764706
# 100                 1250  27250.588235
# ...                  ...           ...
# 2299                1180  14544.352941
# 2300                1080  13827.882353
# 2301                 780  12180.000000
# 2302                1020  13398.000000
# 2303                 810  12180.000000
#
# [216 rows x 8 columns]

# %% [markdown]
# #### Посмотрим какие объемы производства характерны сотрудникам, которые работают при вредности 0 балов и какие у них разряды:

# %%
people = data_v0['FIO'].unique()

fig, axes = plt.subplots(figsize=(11, 7), nrows=2)
ax = axes[0]
ax.scatter('Объем производства', 'FIO', data=data_v0)
ax.set_xticks(data_v0['Объем производства'].unique())
ax.set_xticklabels(labels=data_v0['Объем производства'].unique(), rotation=90)
ax.set_title('Объем производства', fontsize=12)

ax = axes[1]
ax.scatter('Разряд', 'FIO', data=data_v0)
ax.set_xticks(data_v0.Разряд.unique())
ax.set_title('Разряд', fontsize=12)

plt.tight_layout()
plt.show()

# %%
ops = []
f1 = data_v0['Объем производства'] == 1250
f2 = data_v0['Объем производства'] == 1200
for p in people:
    f3 = data_v0.FIO == p
    x = data_v0.Доход.loc[f1&f3].values[0]
    y = data_v0.Доход.loc[f2&f3].values[0]
    r = data_v0.Разряд.loc[data_v0.FIO == p].values[0]
    o = data_v0.Оборудование.loc[data_v0.FIO == p].values[0]
    op = (x-y)/50
    ops.append(op)
    print(f'{p} - {op:.2f}  - {r} разряд - {o}')

ops.sort()
ops
# Out:
# Антонов В. Т. - 12.98  - 7 разряд - Контрольно-измерительная аппаратура
# Белкин Г. В. - 12.98  - 7 разряд - Контрольно-измерительная аппаратура
# Горюнов Д. Т. - 13.63  - 7 разряд - Контрольно-измерительная аппаратура
# Григорьев А. Т. - 7.16  - 3 разряд - Вспомогательные помещения
# Гусев Р. И. - 12.98  - 7 разряд - Контрольно-измерительная аппаратура
# Журавлев Б. И. - 7.16  - 3 разряд - Вспомогательные помещения
# Клюев Д. М. - 7.16  - 3 разряд - Вспомогательные помещения
# Кондратьев Д. Д. - 7.52  - 3 разряд - Вспомогательные помещения
# Лазарев А. Н. - 13.63  - 7 разряд - Контрольно-измерительная аппаратура
# Львов А. С. - 7.16  - 3 разряд - Вспомогательные помещения
# Марков И. П. - 13.63  - 7 разряд - Контрольно-измерительная аппаратура
# Наумов О. В. - 7.16  - 3 разряд - Вспомогательные помещения
# Осипов М. А. - 12.98  - 7 разряд - Контрольно-измерительная аппаратура
# Соколов Ф. М. - 13.63  - 7 разряд - Контрольно-измерительная аппаратура
# Степанов А. М. - 7.52  - 3 разряд - Вспомогательные помещения
# Федотов М. М. - 7.88  - 3 разряд - Вспомогательные помещения
# Филиппов И. П. - 14.27  - 7 разряд - Контрольно-измерительная аппаратура
# Чернышев Д. В. - 7.16  - 3 разряд - Вспомогательные помещения
# [7.1647058823538465,
#  7.1647058823538465,
#  7.1647058823538465,
#  7.1647058823538465,
#  7.1647058823538465,
#  7.1647058823538465,
#  7.522941176471104,
#  7.522941176471104,
#  7.881176470588507,
#  12.976470588234587,
#  12.976470588234587,
#  12.976470588234587,
#  12.976470588234587,
#  13.625294117646117,
#  13.625294117646117,
#  13.625294117646117,
#  13.625294117646117,
#  14.274117647057793]

# %% [markdown]
# #### Стоимость 1 ед. объема производства между значениями на уровнях 1250 и 1200 у всех разная.
# #### Проверим на примере одного сотрудника, Например, Антонова В. Т.:

# %%
antonov = data_v0.loc[data_v0.FIO == 'Антонов В. Т.']
antonov
# Out:
#                FIO Месяц                             Профессия Разряд  \
# 96   Антонов В. Т.     1  Контролер качества готовой продукции      7
# 97   Антонов В. Т.     2  Контролер качества готовой продукции      7
# 98   Антонов В. Т.     3  Контролер качества готовой продукции      7
# 99   Антонов В. Т.     4  Контролер качества готовой продукции      7
# 100  Антонов В. Т.     5  Контролер качества готовой продукции      7
# 101  Антонов В. Т.     6  Контролер качества готовой продукции      7
# 102  Антонов В. Т.     7  Контролер качества готовой продукции      7
# 103  Антонов В. Т.     8  Контролер качества готовой продукции      7
# 104  Антонов В. Т.     9  Контролер качества готовой продукции      7
# 105  Антонов В. Т.    10  Контролер качества готовой продукции      7
# 106  Антонов В. Т.    11  Контролер качества готовой продукции      7
# 107  Антонов В. Т.    12  Контролер качества готовой продукции      7
#
#                             Оборудование  Вредность (балл.)  \
# 96   Контрольно-измерительная аппаратура                  0
# 97   Контрольно-измерительная аппаратура                  0
# 98   Контрольно-измерительная аппаратура                  0
# 99   Контрольно-измерительная аппаратура                  0
# 100  Контрольно-измерительная аппаратура                  0
# 101  Контрольно-измерительная аппаратура                  0
# 102  Контрольно-измерительная аппаратура                  0
# 103  Контрольно-измерительная аппаратура                  0
# 104  Контрольно-измерительная аппаратура                  0
# 105  Контрольно-измерительная аппаратура                  0
# 106  Контрольно-измерительная аппаратура                  0
# 107  Контрольно-измерительная аппаратура                  0
#
#      Объем производства         Доход
# 96                  580  22060.000000
# 97                  790  22060.000000
# 98                  820  22060.000000
# 99                 1200  26601.764706
# 100                1250  27250.588235
# 101                 950  23357.647059
# 102                1400  29197.058824
# 103                1180  26342.235294
# 104                1080  25044.588235
# 105                 780  22060.000000
# 106                1020  24266.000000
# 107                 810  22060.000000

# %%
# 1250 - 1200 = 50
(27250-26601)/50
# Out:
# 12.98

# %%
# 1080 - 1020 = 60
(25044-24266)/60
# Out:
# 12.966666666666667

# %%
# 1400 - 950 = 450
(29197-23357)/450
# Out:
# 12.977777777777778

# %%
# 950 - 820 = 70
(23357-22060)/70
# Out:
# 18.52857142857143

# %% [markdown]
# #### Есть закономерность - стоимость единицы объема производства равна 13 (округл.), влияние объема производства оказывается НЕ с уровня 820. С какого?

# %%
# 950 & 850 = 100
(23357-22060)/100
# Out:
# 12.97

# %% [markdown]
# #### С уровня __850__.

# %% [markdown]
# ## Анализ зависимости дохода от разряда

# %%
dataBezVred = data.copy()
dataBezVred['Доход'] = dataBezVred['Доход'] - dataBezVred['Вредность (балл.)']*180
dataBezVred = dataBezVred.loc[dataBezVred['Объем производства']<850]
dataBezVred['Доход'] = dataBezVred['Доход'].astype('float')
dataBezVred['Доход'] = round(dataBezVred['Доход'], 1)

raz = dataBezVred.Разряд.unique().tolist()
raz.sort()

print('Profits:')
profits = {}
for i, r in enumerate(raz):
    prof = [round(d, 1) for d in dataBezVred.loc[data.Разряд==r]['Доход'].unique()]
    prof = list(set(prof))
    prof.sort()
    profits.update({r:prof})
    print(f'{r} : {prof}')  

print()
print('Tariffs:')
tariff = {}
for k, v in profits.items():
    tariff.update({k:v[0]})
    print(f'{k} : {v[0]}')
# Out:
# Profits:
# 3 : [12180.0, 12789.0, 13398.0]
# 4 : [14130.0, 14836.5, 15543.0]
# 5 : [16390.0, 17209.5, 18029.0]
# 6 : [19020.0, 19971.0, 20922.0]
# 7 : [22060.0, 23163.0, 24266.0]
#
# Tariffs:
# 3 : 12180.0
# 4 : 14130.0
# 5 : 16390.0
# 6 : 19020.0
# 7 : 22060.0

# %% [markdown]
# #### оклады (тарифы):
# 1) 3 разряд - 12180;   + 5% - 12789;   + 10% 13398;
# 1) 4 разряд - 14130; ...
# 1) 5 разряд - 16390; ...
# 1) 6 разряд - 19020; ...
# 1) 7 разряд - 22060; ...
#
# #### в каждом разряде есть надбавки 5% и 10%

# %%
for r in raz:
    print(f'raz = {r}')
    for i in range(1, len(profits[r])):
        print(f'{profits[r][i]}/{profits[r][0]}={profits[r][i]/profits[r][0]}')
# Out:
# raz = 3
# 12789.0/12180.0=1.05
# 13398.0/12180.0=1.1
# raz = 4
# 14836.5/14130.0=1.05
# 15543.0/14130.0=1.1
# raz = 5
# 17209.5/16390.0=1.05
# 18029.0/16390.0=1.1
# raz = 6
# 19971.0/19020.0=1.05
# 20922.0/19020.0=1.1
# raz = 7
# 23163.0/22060.0=1.05
# 24266.0/22060.0=1.1

# %% [markdown]
# #### от чего могут зависеть надбаки?

# %%
to_show = ['FIO', 'Месяц', 'Профессия', 'Оборудование', 'Вредность (балл.)',]

# many data
# for r in raz:
#     for p in profits[r]:
#         print(f'raz = {r}, profit = {p}')
#         print(dataBezVred.loc[dataBezVred.Доход==p][to_show])

# %% [markdown]
# #### по всей видимости надбавка 5 и 10% - индивидуальные условия, т.к. среди всех категорий доходов (без учета вредности и объема производства) зависимостей от прочих факторов не выявлено (кроме разряда и FIO);
# #### Разделим записи на 3 категории в зависимости от бонуса (0%, 5% и 10%)

# %%
dataBezVred['Коэф. надбавки'] = 1

for r in raz:
    for i, p in enumerate(profits[r]):
        mask = dataBezVred['Доход'] == p
        if i == 1:
            dataBezVred.loc[mask, 'Коэф. надбавки'] = 1.05
        elif i == 2:
            dataBezVred.loc[mask, 'Коэф. надбавки'] = 1.1
        else:
            continue
            
dataBezVred
# Out:
#                 FIO Месяц              Профессия Разряд        Оборудование  \
# 0     Абрамов Е. Д.     1                Уборщик      3  Пилигримовые станы
# 1     Абрамов Е. Д.     2                Уборщик      3  Пилигримовые станы
# 2     Абрамов Е. Д.     3                Уборщик      3  Пилигримовые станы
# 9     Абрамов Е. Д.    10                Уборщик      3  Пилигримовые станы
# 11    Абрамов Е. Д.    12                Уборщик      3  Пилигримовые станы
# ...             ...   ...                    ...    ...                 ...
# 2388  Яковлев Д. И.     1  Подручный вальцовщика      4      Прошивной стан
# 2389  Яковлев Д. И.     2  Подручный вальцовщика      4      Прошивной стан
# 2390  Яковлев Д. И.     3  Подручный вальцовщика      4      Прошивной стан
# 2397  Яковлев Д. И.    10  Подручный вальцовщика      4      Прошивной стан
# 2399  Яковлев Д. И.    12  Подручный вальцовщика      4      Прошивной стан
#
#       Вредность (балл.)  Объем производства    Доход  Коэф. надбавки
# 0                    18                 580  13398.0             1.1
# 1                    18                 790  13398.0             1.1
# 2                    18                 820  13398.0             1.1
# 9                    18                 780  13398.0             1.1
# 11                   18                 810  13398.0             1.1
# ...                 ...                 ...      ...             ...
# 2388                 18                 580  15543.0             1.1
# 2389                 18                 790  15543.0             1.1
# 2390                 18                 820  15543.0             1.1
# 2397                 18                 780  15543.0             1.1
# 2399                 18                 810  15543.0             1.1
#
# [1000 rows x 9 columns]

# %% [markdown]
# #### Преобразование затронуло всех возможных сотрудников? Сравним по именам:

# %%
names = dataBezVred.FIO.unique()
allnames = data.FIO.unique()
print(len(names) == len(allnames))
# Out:
# True

# %% [markdown]
# #### Длины списков уникальных имен совпадают => всем сотруникам была присвоена соответствующая категория. Присвоим категории всем записям в генеральном датасете.

# %%
data['Коэф. надбавки'] = None

for name in allnames:
    mask1 = dataBezVred['FIO'] == name
    mask2 = data['FIO'] == name
    coef = dataBezVred.loc[mask1]['Коэф. надбавки'].tolist()[0]
    data.loc[mask2, 'Коэф. надбавки'] = coef

# %% [markdown]
# ## Анализ зависимости дохода от объема производства (ч. 2)

# %%
data_coef1 = data.loc[data['Коэф. надбавки'] == 1]
data_coef1 = data_coef1.loc[data_coef1['Объем производства'] > 850]
data_coef1['Доход'] -= data_coef1['Вредность (балл.)'] * 180
data_coef1['Доход'] = round(data_coef1['Доход'], 1)
data_coef1
# Out:
#                  FIO Месяц   Профессия Разряд        Оборудование  \
# 27    Агафонов С. И.     4  Вальцовщик      6  Пилигримовые станы
# 28    Агафонов С. И.     5  Вальцовщик      6  Пилигримовые станы
# 29    Агафонов С. И.     6  Вальцовщик      6  Пилигримовые станы
# 30    Агафонов С. И.     7  Вальцовщик      6  Пилигримовые станы
# 31    Агафонов С. И.     8  Вальцовщик      6  Пилигримовые станы
# ...              ...   ...         ...    ...                 ...
# 2369  Щербаков А. М.     6  Вальцовщик      5  Калибровочный стан
# 2370  Щербаков А. М.     7  Вальцовщик      5  Калибровочный стан
# 2371  Щербаков А. М.     8  Вальцовщик      5  Калибровочный стан
# 2372  Щербаков А. М.     9  Вальцовщик      5  Калибровочный стан
# 2374  Щербаков А. М.    11  Вальцовщик      5  Калибровочный стан
#
#       Вредность (балл.)  Объем производства    Доход Коэф. надбавки
# 27                   18                1200  22935.9            1.0
# 28                   18                1250  23495.3            1.0
# 29                   18                 950  20138.8            1.0
# 30                   18                1400  25173.5            1.0
# 31                   18                1180  22712.1            1.0
# ...                 ...                 ...      ...            ...
# 2369                 18                 950  17354.1            1.0
# 2370                 18                1400  21692.6            1.0
# 2371                 18                1180  19571.6            1.0
# 2372                 18                1080  18607.5            1.0
# 2374                 18                1020  18029.0            1.0
#
# [700 rows x 9 columns]

# %% [markdown]
#  #### Уровень, с которого объем производства влияет на доход - 850
#  #### Еще раз проанализируем показатели сотрудника Антонова В. Т.

# %%
data_coef1[data_coef1['FIO']== 'Антонов В. Т.']
# Out:
#                FIO Месяц                             Профессия Разряд  \
# 99   Антонов В. Т.     4  Контролер качества готовой продукции      7
# 100  Антонов В. Т.     5  Контролер качества готовой продукции      7
# 101  Антонов В. Т.     6  Контролер качества готовой продукции      7
# 102  Антонов В. Т.     7  Контролер качества готовой продукции      7
# 103  Антонов В. Т.     8  Контролер качества готовой продукции      7
# 104  Антонов В. Т.     9  Контролер качества готовой продукции      7
# 106  Антонов В. Т.    11  Контролер качества готовой продукции      7
#
#                             Оборудование  Вредность (балл.)  \
# 99   Контрольно-измерительная аппаратура                  0
# 100  Контрольно-измерительная аппаратура                  0
# 101  Контрольно-измерительная аппаратура                  0
# 102  Контрольно-измерительная аппаратура                  0
# 103  Контрольно-измерительная аппаратура                  0
# 104  Контрольно-измерительная аппаратура                  0
# 106  Контрольно-измерительная аппаратура                  0
#
#      Объем производства    Доход Коэф. надбавки
# 99                 1200  26601.8            1.0
# 100                1250  27250.6            1.0
# 101                 950  23357.6            1.0
# 102                1400  29197.1            1.0
# 103                1180  26342.2            1.0
# 104                1080  25044.6            1.0
# 106                1020  24266.0            1.0

# %%
tarif = profits[7][0]

x = 1200 - 850
(26601.8-tarif)/x
# Out:
# 12.976571428571427

# %%
x = 1400 - 850
(29197.1-tarif)/x
# Out:
# 12.976545454545452

# %% [markdown]
# #### Как и в прошлый раз стоимость 1 ед объема производства равна 13.
# #### Выберем другого сотрудника, например, Щербакова А. М.

# %%
data_coef1[data_coef1['FIO']== 'Щербаков А. М.']
# Out:
#                  FIO Месяц   Профессия Разряд        Оборудование  \
# 2367  Щербаков А. М.     4  Вальцовщик      5  Калибровочный стан
# 2368  Щербаков А. М.     5  Вальцовщик      5  Калибровочный стан
# 2369  Щербаков А. М.     6  Вальцовщик      5  Калибровочный стан
# 2370  Щербаков А. М.     7  Вальцовщик      5  Калибровочный стан
# 2371  Щербаков А. М.     8  Вальцовщик      5  Калибровочный стан
# 2372  Щербаков А. М.     9  Вальцовщик      5  Калибровочный стан
# 2374  Щербаков А. М.    11  Вальцовщик      5  Калибровочный стан
#
#       Вредность (балл.)  Объем производства    Доход Коэф. надбавки
# 2367                 18                1200  19764.4            1.0
# 2368                 18                1250  20246.5            1.0
# 2369                 18                 950  17354.1            1.0
# 2370                 18                1400  21692.6            1.0
# 2371                 18                1180  19571.6            1.0
# 2372                 18                1080  18607.5            1.0
# 2374                 18                1020  18029.0            1.0

# %%
tarif = profits[5][0]
x = 1200 - 850
(19764.4-tarif)/x
# Out:
# 9.641142857142862

# %%
x = 1400 - 850
(21692.6-tarif)/x
# Out:
# 9.641090909090906

# %% [markdown]
# #### Закономерность есть, но она отличается от Антонова. Дело в разряде?

# %%
data_coef1[data_coef1['Разряд'] == 7]
# Out:
#                 FIO Месяц             Профессия Разряд         Оборудование  \
# 39    Аксенов Е. Н.     4  Нагревальщик металла      7  Нагревательные печи
# 40    Аксенов Е. Н.     5  Нагревальщик металла      7  Нагревательные печи
# 41    Аксенов Е. Н.     6  Нагревальщик металла      7  Нагревательные печи
# 42    Аксенов Е. Н.     7  Нагревальщик металла      7  Нагревательные печи
# 43    Аксенов Е. Н.     8  Нагревальщик металла      7  Нагревательные печи
# ...             ...   ...                   ...    ...                  ...
# 2285   Чернов С. Е.     6  Нагревальщик металла      7  Нагревательные печи
# 2286   Чернов С. Е.     7  Нагревальщик металла      7  Нагревательные печи
# 2287   Чернов С. Е.     8  Нагревальщик металла      7  Нагревательные печи
# 2288   Чернов С. Е.     9  Нагревальщик металла      7  Нагревательные печи
# 2290   Чернов С. Е.    11  Нагревальщик металла      7  Нагревательные печи
#
#       Вредность (балл.)  Объем производства    Доход Коэф. надбавки
# 39                   22                1200  26601.8            1.0
# 40                   22                1250  27250.6            1.0
# 41                   22                 950  23357.6            1.0
# 42                   22                1400  29197.1            1.0
# 43                   22                1180  26342.2            1.0
# ...                 ...                 ...      ...            ...
# 2285                 22                 950  23357.6            1.0
# 2286                 22                1400  29197.1            1.0
# 2287                 22                1180  26342.2            1.0
# 2288                 22                1080  25044.6            1.0
# 2290                 22                1020  24266.0            1.0
#
# [112 rows x 9 columns]

# %% [markdown]
# ####  Очевидно, доходы по 7 разряду совпадают, т.е. возможно стоимость еденицы объема производства для каждого разряда своя. Проверим:

# %%
data_coef1[data_coef1['Разряд'] == 6]
# Out:
#                  FIO Месяц   Профессия Разряд        Оборудование  \
# 27    Агафонов С. И.     4  Вальцовщик      6  Пилигримовые станы
# 28    Агафонов С. И.     5  Вальцовщик      6  Пилигримовые станы
# 29    Агафонов С. И.     6  Вальцовщик      6  Пилигримовые станы
# 30    Агафонов С. И.     7  Вальцовщик      6  Пилигримовые станы
# 31    Агафонов С. И.     8  Вальцовщик      6  Пилигримовые станы
# ...              ...   ...         ...    ...                 ...
# 2021  Степанов Т. Т.     6  Вальцовщик      6  Пилигримовые станы
# 2022  Степанов Т. Т.     7  Вальцовщик      6  Пилигримовые станы
# 2023  Степанов Т. Т.     8  Вальцовщик      6  Пилигримовые станы
# 2024  Степанов Т. Т.     9  Вальцовщик      6  Пилигримовые станы
# 2026  Степанов Т. Т.    11  Вальцовщик      6  Пилигримовые станы
#
#       Вредность (балл.)  Объем производства    Доход Коэф. надбавки
# 27                   18                1200  22935.9            1.0
# 28                   18                1250  23495.3            1.0
# 29                   18                 950  20138.8            1.0
# 30                   18                1400  25173.5            1.0
# 31                   18                1180  22712.1            1.0
# ...                 ...                 ...      ...            ...
# 2021                 18                 950  20138.8            1.0
# 2022                 18                1400  25173.5            1.0
# 2023                 18                1180  22712.1            1.0
# 2024                 18                1080  21593.3            1.0
# 2026                 18                1020  20922.0            1.0
#
# [91 rows x 9 columns]

# %% [markdown]
# #### По остальным разрядам - аналогичная картина, значит нужно вычислить стоимость единицы объема производства сверх нормы (850) для каждого разряда:

# %%
value_produciton = {}

for r in raz:
    mask1 = data_coef1['Разряд'] == r
    mask2 = data_coef1['Объем производства'] == 1250
    mask3 = data_coef1['Объем производства'] == 1200
    value = ((data_coef1.loc[mask1&mask2,  'Доход'].values[0] -
             data_coef1.loc[mask1&mask3,  'Доход'].values[0]) / 50)
    value_produciton[r] = value
 

    
# Коррекция стоимости для 3 разряда
# value_produciton[3] = 7.16
value_produciton
# Out:
# {3: 7.165999999999985,
#  4: 8.312000000000044,
#  5: 9.641999999999971,
#  6: 11.187999999999956,
#  7: 12.975999999999985}

# %% [markdown]
# #### Добавим в генеральный датасет все ранее расчитанные показатели и слобец "Проверка", в котором будут отражены результаты расчета по предполагаемой формуле. Для того чтобы проверить результаты посмотрим на срез и 50 случайных записей и сравним колонки "Доход" и "Проверка"

# %%
data['Тариф'] = 0
data['Объем П > 850'] = 0
data['Стоимость единицы объема П'] = 0
data['Проверка'] = 0


for r in raz:
    mask1 = data['Разряд'] == r
    data.loc[mask1, 'Тариф'] = tariff[r]
    data.loc[mask1, 'Стоимость единицы объема П'] = value_produciton[r]
    
    mask2 = data['Объем производства'] >= 850
    data.loc[mask2, 'Объем П > 850'] = 1
    

k = data['Коэф. надбавки']
T = data['Тариф']
V = data['Вредность (балл.)']
TF = data['Объем П > 850']
O = data['Объем производства']
cost = data['Стоимость единицы объема П']

data['Проверка'] = k*(T+TF*cost*(O-850))+180*V

to_show = ['FIO', 'Месяц', 'Профессия', 'Разряд', 
           'Оборудование', 'Вредность (балл.)', 
           'Объем производства', 'Доход', 'Проверка']

data_check = data.sample(50)
data_check[to_show]
# Out:
#                    FIO Месяц                             Профессия Разряд  \
# 900      Комаров Л. Ф.     1                  Нагревальщик металла      6
# 464      Горюнов Д. Т.     9  Контролер качества готовой продукции      7
# 1482      Носков К. К.     7                 Подручный вальцовщика      4
# 365     Воробьев А. О.     6                 Подручный вальцовщика      3
# 2140     Федотов М. К.     5               Резчик горячего металла      4
# 1269      Марков И. П.    10  Контролер качества готовой продукции      7
# 2018    Степанов Т. Т.     3                            Вальцовщик      6
# 1549      Осипов М. А.     2  Контролер качества готовой продукции      7
# 1430     Новиков А. В.     3                  Нагревальщик металла      4
# 680       Иванов П. А.     9                           Огнеупорщик      4
# 1373      Наумов О. В.     6                               Уборщик      3
# 1248    Максимов Р. М.     1                  Нагревальщик металла      7
# 125       Белкин В. И.     6                            Вальцовщик      7
# 1233     Макаров М. Д.    10               Резчик горячего металла      4
# 1214       Львов А. С.     3                               Уборщик      3
# 1130     Лазарев Д. А.     3                  Нагревальщик металла      5
# 1164     Лебедев М. Д.     1                  Нагревальщик металла      5
# 1643      Петров А. Е.    12                            Вальцовщик      7
# 226        Быков Л. Н.    11                 Подручный вальцовщика      3
# 2062     Терехов И. К.    11             Оператор поста управления      4
# 1915     Соколов С. Д.     8                  Нагревальщик металла      6
# 733      Калинин Г. Н.     2                 Подручный вальцовщика      4
# 2133     Федоров А. А.    10             Оператор поста управления      5
# 2316    Чистяков Я. Я.     1                 Подручный вальцовщика      3
# 977      Косарев А. М.     6                  Нагревальщик металла      7
# 1902     Соколов И. А.     7                           Огнеупорщик      4
# 2379       Щукин К. С.     4             Оператор поста управления      5
# 2090   Третьяков В. А.     3                            Вальцовщик      5
# 71      Алексеев Н. Н.    12                  Нагревальщик металла      5
# 816       Козлов А. Н.     1                  Нагревальщик металла      7
# 1147     Лазарев И. А.     8                 Подручный вальцовщика      3
# 1136     Лазарев Д. А.     9                  Нагревальщик металла      5
# 1351    Муравьев В. Б.     8                 Подручный вальцовщика      3
# 2242     Хомяков Э. К.    11                 Подручный вальцовщика      4
# 1614       Панов Я. Ф.     7                  Нагревальщик металла      7
# 986      Краснов И. М.     3                               Уборщик      3
# 1449     Новиков А. Ф.    10                            Вальцовщик      7
# 575      Ермаков Г. И.    12                 Подручный вальцовщика      4
# 944      Копылов А. А.     9                            Вальцовщик      6
# 2261      Чернов И. А.     6                  Нагревальщик металла      7
# 1656       Попов Е. Ю.     1                            Вальцовщик      7
# 920   Кондратьев Д. Д.     9                               Уборщик      3
# 895      Комаров Д. К.     8             Оператор поста управления      5
# 1471     Новиков С. М.     8                 Подручный вальцовщика      4
# 1633      Петров А. Е.     2                            Вальцовщик      7
# 2142     Федотов М. К.     7               Резчик горячего металла      4
# 860     Колпаков И. А.     9                  Нагревальщик металла      4
# 433      Голиков Г. И.     2                  Нагревальщик металла      4
# 1601  Павловский Д. А.     6                               Уборщик      3
# 2296    Чернышев Д. В.     5                               Уборщик      3
#
#                              Оборудование  Вредность (балл.)  \
# 900                   Нагревательные печи                 22
# 464   Контрольно-измерительная аппаратура                  0
# 1482                   Пилигримовые станы                 18
# 365                    Пилигримовые станы                 18
# 2140                   Пилигримовые станы                 16
# 1269  Контрольно-измерительная аппаратура                  0
# 2018                   Пилигримовые станы                 18
# 1549  Контрольно-измерительная аппаратура                  0
# 1430                  Нагревательные печи                 22
# 680                   Нагревательные печи                 11
# 1373            Вспомогательные помещения                  0
# 1248                  Нагревательные печи                 22
# 125                    Пилигримовые станы                 18
# 1233                   Пилигримовые станы                 16
# 1214            Вспомогательные помещения                  0
# 1130        Нагревательные печи, кантовка                 22
# 1164          Нагревательные печи, нагрев                 22
# 1643                   Пилигримовые станы                 18
# 226                    Пилигримовые станы                 18
# 2062                   Калибровочный стан                  8
# 1915                  Нагревательные печи                 22
# 733                        Прошивной стан                 18
# 2133                   Калибровочный стан                  8
# 2316                   Пилигримовые станы                 18
# 977                   Нагревательные печи                 22
# 1902                  Нагревательные печи                 11
# 2379              Калибровочный стан, ГРП                  8
# 2090                   Калибровочный стан                 18
# 71          Нагревательные печи, кантовка                 22
# 816                   Нагревательные печи                 22
# 1147                   Пилигримовые станы                 18
# 1136        Нагревательные печи, кантовка                 22
# 1351                   Пилигримовые станы                 18
# 2242                       Прошивной стан                 18
# 1614                  Нагревательные печи                 22
# 986                    Пилигримовые станы                 18
# 1449                       Прошивной стан                 18
# 575                    Пилигримовые станы                 18
# 944                        Прошивной стан                 18
# 2261                  Нагревательные печи                 22
# 1656                       Прошивной стан                 18
# 920             Вспомогательные помещения                  0
# 895                    Калибровочный стан                  8
# 1471                       Прошивной стан                 18
# 1633                   Пилигримовые станы                 18
# 2142                   Пилигримовые станы                 16
# 860                   Нагревательные печи                 22
# 433                   Нагревательные печи                 22
# 1601                   Пилигримовые станы                 18
# 2296            Вспомогательные помещения                  0
#
#       Объем производства         Доход   Проверка
# 900                  580  23931.000000    23931.0
# 464                 1080  26296.817647  26296.704
# 1482                1400  22876.544118   22876.68
# 365                  950  16136.470588    16136.6
# 2140                1250  21207.441176   21207.54
# 1269                 780  23163.000000    23163.0
# 2018                 820  22260.000000    22260.0
# 1549                 790  22060.000000    22060.0
# 1430                 820  18090.000000    18090.0
# 680                 1080  19625.876471  19625.936
# 1373                 950  12896.470588    12896.6
# 1248                 580  26020.000000    26020.0
# 125                  950  26597.647059    26597.6
# 1233                 780  17010.000000    17010.0
# 1214                 820  12180.000000    12180.0
# 1130                 820  20350.000000    20350.0
# 1164                 580  20350.000000    20350.0
# 1643                 810  25300.000000    25300.0
# 226                 1020  16638.000000   16638.22
# 2062                1020  16983.000000   16983.04
# 1915                1180  26672.117647   26672.04
# 733                  790  18076.500000    18076.5
# 2133                 780  17830.000000    17830.0
# 2316                 580  15420.000000    15420.0
# 977                  950  28485.529412   28485.48
# 1902                1400  20681.470588    20681.6
# 2379                1200  22192.632353  22192.935
# 2090                 820  20449.500000    20449.5
# 71                   810  20350.000000    20350.0
# 816                  580  27123.000000    27123.0
# 1147                1180  19238.788235  19239.258
# 1136                1080  22567.470588   22567.66
# 1351                1180  17784.352941   17784.78
# 2242                1020  18783.000000   18783.04
# 1614                1400  33157.058824    33156.8
# 986                  820  15420.000000    15420.0
# 1449                 780  26403.000000    26403.0
# 575                  810  17370.000000    17370.0
# 944                 1080  24833.294118   24833.24
# 2261                 950  29653.411765   29653.36
# 1656                 580  26403.000000    26403.0
# 920                 1080  14519.276471  14519.589
# 895                 1180  21011.588235   21011.86
# 1471                1180  20956.526471  20956.608
# 1633                 790  25300.000000    25300.0
# 2142                1400  22516.544118   22516.68
# 860                 1080  20001.705882   20001.76
# 433                  790  18796.500000    18796.5
# 1601                 950  16781.294118   16781.43
# 2296                1250  15045.882353    15046.4

# %% [markdown]
# ## Результат
#
# Общая формула расчета Дохода:
#
# $$
#     D = k_1*(T+k_2*C*(O-850))+180*V
# $$
#
# где
#
# __D__ - доход;<br>
# __$k_1$__ - индивидуальный коэффициент надбавки: 0% 5% 10% (зависит от работника);<br>
# __T__ - тарифная ставка (зависит от раязряда);<br>
# __$k_2$__ - коэффициент перевыполнения объема производства (1 - да, 0 - нет) при норме 850;<br>
# __C__ - стоимость единицы объема производства (зависит от разряда);<br>
# __O__ - объем производства;<br>
# __V__ - вредность (стоимость 1 балла = 180);<br>

# %%
# Тарифы (разряд: значение)
tariff
# Out:
# {3: 12180.0, 4: 14130.0, 5: 16390.0, 6: 19020.0, 7: 22060.0}

# %%
# Стоимость за единицу объема производства (разряд: стоимость)
value_produciton
# Out:
# {3: 7.165999999999985,
#  4: 8.312000000000044,
#  5: 9.641999999999971,
#  6: 11.187999999999956,
#  7: 12.975999999999985}
